# %% [markdown]
# #Imports

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# #Widgets

# %%
dbutils.widgets.removeAll()

# %%
dbutils.widgets.text("storageName", "adlsecommerceproject")
dbutils.widgets.text("container","raw")
dbutils.widgets.text("catalog","catalog_ecommerce")
dbutils.widgets.text("schema","bronze")

# %% [markdown]
# #Constantes

# %%
storageName = dbutils.widgets.get("storageName")
container = dbutils.widgets.get("container")
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")

# %% [markdown]
# #Estructura

# %%
customer_schema = StructType(fields=[
    StructField("customer_id", StringType(), False),
    StructField("customer_unique_id", StringType(),False),
    StructField("customer_zip_code_prefix", StringType(),False),
    StructField("customer_city", StringType(),False),
    StructField("customer_state", StringType(), False)
            
])

# %% [markdown]
# #Leer CSV

# %%
df_customer = spark.read.option('header', True).schema(customer_schema).csv(f"abfss://{container}@{storageName}.dfs.core.windows.net/customers")

# %% [markdown]
# #Guardar Tabla

# %%
df_customer.write.mode("overwrite").saveAsTable(f"{catalog}.{schema}.customer")
