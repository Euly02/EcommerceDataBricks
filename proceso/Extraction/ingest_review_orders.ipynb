# %% [markdown]
# #Imports

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# #Widgets

# %%
dbutils.widgets.removeAll()
dbutils.widgets.text("storageName", "adlsecommerceproject")
dbutils.widgets.text("container","raw")
dbutils.widgets.text("catalog","catalog_ecommerce")
dbutils.widgets.text("schema","bronze")

# %% [markdown]
# #Constantes

# %%
storageName = dbutils.widgets.get("storageName")
container = dbutils.widgets.get("container")
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")

# %% [markdown]
# #Estructura

# %%
review_schema = StructType(fields=[
    StructField("review_id", StringType(), False),
    StructField("order_id", StringType(), False),
    StructField("review_score", StringType(), False)
])

# %% [markdown]
# #Leer el CSV

# %%
df_reviews = spark.read.option('header', True).schema(review_schema).csv(f"abfss://{container}@{storageName}.dfs.core.windows.net/reviews")

# %% [markdown]
# #Guardar en tabla

# %%
df_reviews.write.mode("overwrite").saveAsTable(f"{catalog}.{schema}.reviews")
