# %% [markdown]
# ###Widgets

# %%
dbutils.widgets.removeAll()

# %%
# %sql
create widget text storageName default "adlsecommerceproject"

# %% [markdown]
# #Catalog y Schemas

# %%
# %sql
create catalog if not exists catalog_ecommerce;

# %%
# %sql
create schema if not exists catalog_ecommerce.bronze;
create schema if not exists catalog_ecommerce.silver;
create schema if not exists catalog_ecommerce.gold;
create schema if not exists catalog_ecommerce.exploratory

# %% [markdown]
# #External Locations

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-raw`
URL 'abfss://raw@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para el container RAW';

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-bronze`
URL 'abfss://bronze@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para el container BRONZE';

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-silver`
URL 'abfss://silver@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para el container SILVER';

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-gold`
URL 'abfss://gold@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para el container GOLD';
